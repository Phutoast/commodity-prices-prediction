# %% [markdown]
# # Exploring The Data
#
# This notebook is used to exploring the dataset. Containing some plots that is useful...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils import explore_data
# Out:
# /Users/phusakulwongtana/anaconda3/envs/chAI/lib/python3.9/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %% [markdown]
# ### Plotting Features PCA

# %%
fig1, ax1 = explore_data.plot_feature_PCA()

# %% [markdown]
# This perfectly the reason why we choose PCA, as the way to do the dimensionality reduction.

# %% [markdown]
# ### Plotting All Data

# %%
fig2, ax2 = explore_data.plot_all_data()

# %% [markdown]
# ### Testing For Stationalities in Dataset

# %%
explore_data.stationary_test(False)
# Out:
#         Commodity       P-Value Is Stationary
# 0       Aluminium  4.767565e-05             ✅
# 1  Carbon Credits  5.997421e-08             ✅
# 2          Copper  1.487202e-05             ✅
# 3           LLDPE  3.882466e-12             ✅
# 4     Natural Gas  1.668624e-10             ✅
# 5          Nickel  1.858101e-06             ✅
# 6       Palladium  2.494475e-09             ✅
# 7        Platinum  5.136346e-08             ✅
# 8             PVC  1.178962e-11             ✅
# 9           Wheat  2.590977e-11             ✅

# %% [markdown]
# ### Testing For Correlations

# %%
fig3, ax3 = explore_data.plot_correlation_all()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-483709c39ba9> in <module>
# ----> 1 explore_data.plot_correlation_all()
#
# ~/Desktop/works/final-project/commodity-prices-prediction/utils/data_visualization.py in wrapper(*args, **kwargs)
#      39         @functools.wraps(func)
#      40         def wrapper(*args, **kwargs):
# ---> 41             out = func(*args, **kwargs)
#      42
#      43             if isinstance(out, tuple):
#
# ~/Desktop/works/final-project/commodity-prices-prediction/utils/explore_data.py in plot_correlation_all()
#     201
#     202     fig, axes = plt.subplots(ncols=num_test, nrows=2, figsize=(20, 10))
# --> 203     list_correlation, list_is_correlated = correlation_over_dataset(test_name, all_test)
#     204
#     205     for name, correlation, is_correlated, ax in zip(test_name, list_correlation, list_is_correlated, axes.T):
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
fig4, ax4 = explore_data.plot_window_unrelated()

# %%
fig5, ax5 = explore_data.plot_window_related()

# %%
fig6, ax6 = explore_data.plot_year_unrelated()

# %%
fig7, ax7 = explore_data.plot_year_related()

# %% [markdown]
# ### Distance Based Metrics

# %%
fig8, ax8 = explore_data.distance_between_time_series()

# %% [markdown]
# ### Clustering
# Using only data point with features. May not convey they whole message, see 👆 plot, where there are differences in trends.

# %%
explore_data.clustering_dataset(num_cluster=4, is_verbose=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4f20b2011ced> in <module>
# ----> 1 explore_data.clustering_dataset(num_cluster=4, is_verbose=False)
#
# ~/Desktop/works/final-project/commodity-prices-prediction/utils/explore_data.py in clustering_dataset(is_side_by_side, num_cluster, is_verbose, use_all_data)
#     560     all_test = [stats.pearsonr, stats.spearmanr, stats.kendalltau]
#     561     test_name = ["Peason", "Spearman", "Kendell"]
# --> 562     list_correlation, _ = correlation_over_dataset(test_name, all_test)
#     563     run_cluster(test_name, [np.abs(c) for c in list_correlation])
#     564
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
explore_data.clustering_dataset(num_cluster=5, is_verbose=False)

# %% [markdown]
# If we use all data (may take awhile to load) the correlation based clustering (+spectral) does better that the distance based.

# %%
explore_data.clustering_dataset(num_cluster=4, is_verbose=False, use_all_data=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-485241935d45> in <module>
# ----> 1 explore_data.clustering_dataset(num_cluster=4, is_verbose=False, use_all_data=True)
#
# ~/Desktop/works/final-project/commodity-prices-prediction/utils/explore_data.py in clustering_dataset(is_side_by_side, num_cluster, is_verbose, use_all_data)
#     560     all_test = [stats.pearsonr, stats.spearmanr, stats.kendalltau]
#     561     test_name = ["Peason", "Spearman", "Kendell"]
# --> 562     list_correlation, _ = correlation_over_dataset(test_name, all_test)
#     563     run_cluster(test_name, [np.abs(c) for c in list_correlation])
#     564
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
explore_data.clustering_dataset(num_cluster=5, is_verbose=False, use_all_data=True)
